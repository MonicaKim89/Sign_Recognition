# %%
import pandas as pd
from image_preprocessing import *

# %%
path = '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/'

# %%
file_list = os.listdir(path)
file_list.sort()
file_list = file_list[1:]
list_file = []
for i in file_list:
    list_file.append(path+i)
list_file.sort()

# %%
list_file
# Out:
# ['/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy1.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy10.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy11.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy12.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy13.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy14.jpg',
#  '/Users/monica_air/Documents/Sign recognition/augmentation/myData/0/0_147023382-fragile-icon-flat-vector-template-design-trendy15.jpg',
# ...
