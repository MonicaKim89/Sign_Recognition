# %%
from image_preprocessing import *

# %%
path ='/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/'

# %% [markdown]
# #### code testing

# %%
img_list = get_img(path)
show(img_list[1])

# %%
direct_show('/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/captured.JPG')

# %%
import cv2 
import numpy as np 
from img_aug import Img_aug
import imgaug.augmenters as iaa

# %%
count_img(path)
# Out:
# 이미지수 19

# %%
file_list = os.listdir(path)
file_list.sort()
file_list = file_list[1:]
list_file = []
for i in file_list:
    list_file.append(path+i)
list_file.sort()
print(list_file)
# Out:
# ['/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/147023382-fragile-icon-flat-vector-template-design-trendy.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/147023383-fragile-icon-flat-vector-template-design-trendy.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/Fragile-icon-vector-by-Hoeda80.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/captured.JPG', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/download.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/fragile-icon-symbol-illustration-design-FX44AE.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/fragile-symbol-line-and-fill-style-icon-2BCYKBD.jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/images (2).jpg', '/Users/monica_air/Documents/Sign recognition/augmentation/0/fragile_icon/images-1.jpg
# ...

# %%
test_ = list_file[0]
test_
type(test_)

test_.split("/")[-1]

file_name=[]
for i in list_file:
    name = i.split("/")[-1].split(".jpg")[0]
    file_name.append(name)
file_name
# Out:
# ['147023382-fragile-icon-flat-vector-template-design-trendy',
#  '147023383-fragile-icon-flat-vector-template-design-trendy',
#  'Fragile-icon-vector-by-Hoeda80',
#  'captured.JPG',
#  'download',
#  'fragile-icon-symbol-illustration-design-FX44AE',
#  'fragile-symbol-line-and-fill-style-icon-2BCYKBD',
#  'images (2)',
#  'images-1',
#  'images-11',
#  'images-2',
#  'images-22',
#  'images-3',
#  'images-4',
#  'images',
#  'imagess',
#  'istockphoto-1208404622-612x612',
#  'md_5afec7f430237',
#  'pngtree-fragile-icon-png-image_2036329']

# %%
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/test_aug_0/'

# test_img = img_list[1]
for i in range (100):
    images_aug = aug.seq.augment_images([img_list[i] for j in range(augment_num)])

    for num,aug_img in enumerate(images_aug):
        cv2.imwrite(save_path+'{}{}.jpg'.format(file_name[num],num),aug_img)

        print('Complete')
# Out:
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-1dc3df8c2b86> in <module>
#       8
#       9     for num,aug_img in enumerate(images_aug):
# ---> 10         cv2.imwrite(save_path+'{}{}.jpg'.format(file_name[num],num),aug_img)
#      11
#      12         print('Complete')
#
# IndexError: list index out of range

# %%
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/test_aug_0/'

for i in range(augment_num):
    images_aug= aug.seq.augment_images([img_list[i] for j in range(augment_num)])
    
    for num, aug_img in enumerate(images_aug):
        cv2.imwrite(save_path+"{}{}.jpg".format(file_name[num],num),aug_img)

        
        print(num, 'complete')
# Out:
# 0 complete
# 1 complete
# 2 complete
# 3 complete
# 4 complete
# 5 complete
# 6 complete
# 7 complete
# 8 complete
# 9 complete
# 10 complete
# 11 complete
# 12 complete
# 13 complete
# 14 complete
# 15 complete
# 16 complete
# 17 complete
# 18 complete
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-86616a0de0f8> in <module>
#       7
#       8     for num, aug_img in enumerate(images_aug):
# ----> 9         cv2.imwrite(save_path+"{}{}.jpg".format(file_name[num],num),aug_img)
#      10
#      11
#
# IndexError: list index out of range

# %%
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/aug_test_0/'

test_img = img_list[1]
images_aug = aug.seq.augment_images([test_img for i in range(augment_num)])
print(type(images_aug))

for num,aug_img in enumerate(images_aug):
    cv2.imwrite(save_path+'test_img_aug{}{}.jpg'.format(num,file_name[num]),aug_img)
    
    print('Complete')
# Out:
# <class 'list'>

# %%
for i in range (10):
    print('{}{}.jpg'.format(file_name[i],i+10))
# Out:
# 147023382-fragile-icon-flat-vector-template-design-trendy.10.jpg
# 147023383-fragile-icon-flat-vector-template-design-trendy.11.jpg
# Fragile-icon-vector-by-Hoeda80.12.jpg
# captured.JPG13.jpg
# download.14.jpg
# fragile-icon-symbol-illustration-design-FX44AE.15.jpg
# fragile-symbol-line-and-fill-style-icon-2BCYKBD.16.jpg
# images (2).17.jpg
# images-1.18.jpg
# images-11.19.jpg

# %%
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/aug_test_0/'

for i in range(19):
    img = img_list[i]
    images_aug = aug.seq.augment_images(img for j in range(augment_num))
    show(images_aug)
#     for num, aug_img in enumerate(images_aug):
#         cv2.imwrite(save_path+'{}{}.jpg'.format(file_name[num],num),aug_img)
#         print(num, 'complete')

# %%
#폴더안 모든 이미지에 대한 augmentation (총 740장)
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/aug_test_0/'

for k in range(19):
    test_img = img_list[k]
    images_aug = aug.seq.augment_images([test_img for i in range(augment_num)])

    for num,aug_img in enumerate(images_aug):
        cv2.imwrite(save_path+'{}{}.jpg'.format(file_name[k],num),aug_img)

        print('{}'.format(file_name[k]), 'Complete')
# Out:
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# 147023382-fragile-icon-flat-vector-template-design-trendy Complete
# ...

# %%
###working
aug = Img_aug()
augment_num = 40
save_path = '/Users/monica_air/Documents/Sign recognition/augmentation/aug_test_0/'

test_img = img_list[3]
images_aug = aug.seq.augment_images([test_img for i in range(augment_num)])

for num,aug_img in enumerate(images_aug):
    cv2.imwrite(save_path+'{}{}.jpg'.format(file_name[3],num),aug_img)
    
    print('Complete')
# Out:
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete
# Complete

# %% [markdown]
# #### Random Data Augmentation

# %%
import imgaug as ia
import imgaug.augmenters as iaa

# %%
#random example images
images = np.random.randint(0,255, (16, 128, 128,3), dtype= np.uint8)

# %% [markdown]
# class Img_aug:
#     def __init__(self):
#         self.sometimes = lambda aug: iaa.Sometimes(0.5, aug)
#         self.seq = iaa.Sequential(
#             [
#                 iaa.Fliplr(0.5),
#                 iaa.Flipud(0.2),
#                 self.sometimes(iaa.CropAndPad(
#                     percent = (-0.05, 0.1),
#                     pad_mode=ia.ALL,
#                     pad_cval = (0,255)
#                 )),
#                 self.somtimes(iaa.Affine(
#                     scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
#                     # scale images to 80-120% of their size, individually per axis
#                     translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
#                     # translate by -20 to +20 percent (per axis)
#                     rotate=(-45, 45),
#                     # rotate by -45 to +45 degrees
#                     shear=(-16, 16), # shear by -16 to +16 degrees
#                     order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
#                     cval=(0, 255), # if mode is constant, use a cval between 0 and 255
#                     mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
#                 )),
#                 iaa.SomeOf((0, 5),
#                     [
#                         self.sometimes(iaa.Superpixels(p_replace=(0, 1.0), n_segments=(20, 200))),
#                         # convert images into their superpixel representation
#                         iaa.OneOf([
#                             iaa.GaussianBlur((0, 3.0)), # blur images with a sigma between 0 and 3.0
#                             iaa.AverageBlur(k=(2, 7)), # blur image using local means with kernel sizes between 2 and 7
#                             iaa.MedianBlur(k=(3, 11)), # blur image using local medians with kernel sizes between 2 and 7
#                         ]),
#                         iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images
#                         iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)), # emboss images # search either for all edges or for directed edges,
#                         # blend the result with the original image using a blobby mask
#                         iaa.SimplexNoiseAlpha(iaa.OneOf([
#                             iaa.EdgeDetect(alpha=(0.5, 1.0)),
#                             iaa.DirectedEdgeDetect(alpha=(0.5, 1.0), direction=(0.0, 1.0)),
#                         ])),
#                         iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5),
#                         # add gaussian noise to images
#                         iaa.OneOf([
#                             iaa.Dropout((0.01, 0.1), per_channel=0.5), # randomly remove up to 10% of the pixels
#                             iaa.CoarseDropout((0.03, 0.15), size_percent=(0.02, 0.05), per_channel=0.2),
#                         ]),
#                         iaa.Invert(0.05, per_channel=True), # invert color channels
#                         iaa.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
#                         iaa.AddToHueAndSaturation((-20, 20)), # change hue and saturation # either change the brightness of the whole image (self.sometimes # per channel) or change the brightness of subareas
#                         iaa.OneOf([
#                             iaa.Multiply((0.5, 1.5), per_channel=0.5),
#                             iaa.FrequencyNoiseAlpha(
#                                 exponent=(-4, 0),
#                                 first=iaa.Multiply((0.5, 1.5), per_channel=True),
#                                 second=iaa.ContrastNormalization((0.5, 2.0))
#                             )
#                         ]),
#                         iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5), # improve or worsen the contrast
#                         iaa.Grayscale(alpha=(0.0, 1.0)),
#                         self.sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)),
#                         # move pixels locally around (with random strengths)
#                         self.sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))), # self.sometimes move parts of the image around
#                         self.sometimes(iaa.PerspectiveTransform(scale=(0.01, 0.1)))
#                     ],
#                     random_order=True
#                 )
#             ],
#             random_order=True
#         )
