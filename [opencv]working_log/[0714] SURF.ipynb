# %% [raw]
# 들어가는 이미지에 따라 성능차이 너무 심함....
# 이미지 사이즈도 신경써야함
# masking방법을 고려해봐야할 듯

# %%
from image_preprocessing import *

# %%
img =cv2.imread('/Users/monica_air/Documents/Sign recognition/opencv/SURF/data/fragile_SURF.png', cv2.COLOR_BGR2RGB)
img2 =cv2.imread("//Users/monica_air/Documents/Sign recognition/opencv/SURF/data/fragile_SURF_full.png", cv2.COLOR_BGR2RGB)

# %%
#ORB detection
orb = cv2.ORB_create()
kp, des = orb.detectAndCompute(img, None)
kp1, des1 = orb.detectAndCompute(img2, None)

#Brute Force Matching
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
matches = bf.match(des, des1)
matches = sorted(matches, key = lambda x : x.distance)

matching_result = cv2.drawMatches(img, kp, img2, kp1, matches, None)
show(matching_result)

# %% [markdown]
# #### ORB

# %%
img =cv2.imread('/Users/monica_air/Documents/Sign recognition/opencv/SURF/data/fragile_SURF.png', cv2.COLOR_BGR2RGB)
img2 =cv2.imread("/Users/monica_air/Documents/Sign recognition/test dataset/logistic_sign_test (2).jpg", cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2, dsize=(640, 480), interpolation=cv2.INTER_AREA)

#ORB detection
orb = cv2.ORB_create()
kp, des = orb.detectAndCompute(img, None)
kp1, des1 = orb.detectAndCompute(img2, None)

#Brute Force Matching
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
matches = bf.match(des, des1)
matches = sorted(matches, key = lambda x : x.distance)

matching_result = cv2.drawMatches(img, kp, img2, kp1, matches, None)
show(matching_result)

# %% [markdown]
# #### SURF

# %%
img =cv2.imread('/Users/monica_air/Documents/Sign recognition/opencv/SURF/data/fragile_SURF.png', cv2.COLOR_BGR2RGB)
img2 =cv2.imread("/Users/monica_air/Documents/Sign recognition/test dataset/logistic_sign_test (2).jpg", cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2, dsize=(640, 480), interpolation=cv2.INTER_AREA)

#SURF detection
surf = cv2.xfeatures2d.SURF_create()
kp, des = surf.detectAndCompute(img, None)
kp_img = cv2.drawKeypoints(img, kp, None)
show(kp_img)
#Brute Force Matching
# bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
# matches = bf.match(des, des1)
# matches = sorted(matches, key = lambda x : x.distance)

# matching_result = cv2.drawMatches(img, kp, img2, kp1, matches, None)
# show(matching_result)

# %%
img1 =cv2.imread('/Users/monica_air/Documents/Sign recognition/opencv/SURF/data/fragile_SURF.png', cv2.COLOR_BGR2RGB)
img2 =cv2.imread("/Users/monica_air/Documents/Sign recognition/test dataset/logistic_sign_test (2).jpg", cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2, dsize=(640, 480), interpolation=cv2.INTER_AREA)

#Gray scale
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#SIFT detection
detector = cv2.xfeatures2d.SIFT_create()
kp1, des1 = sift.detectAndCompute(img, None)
kp2, des2 = sift.detectAndCompute(img2, None)

kp_img = cv2.drawKeypoints(img, kp, None)
kp_img2 = cv2.drawKeypoints(img2, kp1, None)
show(kp_img)
show(kp_img2)

#Brute Force Matching (Matcher)
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck = True)
matches = matcher.match(des1, des2)
res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

show(res)
# 결과 출력 

# matching_result = cv2.drawMatches(img, kp, img2, kp1, matches, None)
# show(matching_result)
