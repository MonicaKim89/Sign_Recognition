# %% [markdown]
# <a href="https://colab.research.google.com/github/MonicaKim89/Sign_Recognition/blob/main/%5B0421%5Dretest_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Projects/Sign Detection/box_detection
# Out:
# /content/drive/MyDrive/Projects/Sign Detection/box_detection

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12897, done.
# remote: Total 12897 (delta 0), reused 0 (delta 0), pack-reused 12897
# Receiving objects: 100% (12897/12897), 11.79 MiB | 7.59 MiB/s, done.
# Resolving deltas: 100% (8960/8960), done.
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5
# HEAD is now at 886f1c0 DDP after autoanchor reorder (#2421)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 596 kB 4.1 MB/s
# Setup complete. Using torch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !unzip post_resized.zip

# %%
# %cat data.yaml
# Out:
# train: /content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/train/images
# val: /content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/val/images
#
# nc: 1
# names: ['box']

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

    print(num_classes)
# Out:
# 1

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/models/yolov5s.yaml
# Out:
# cat: /content/drive/MyDrive/Projects/Sign: No such file or directory
# cat: Detection/box_detection/yolov5/models/yolov5s.yaml: No such file or directory

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5
# !python train.py --img 200 --batch 16 --epochs 100 --data '../data.yaml' --cfg ./models/yolov5l.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5
# github: ⚠️ WARNING: code is out of date by 1003 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/yolov5l.yaml', data='../data.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[200, 200], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5s_results2', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 499 layers, 46631350 parameters, 46631350 gradients, 114.2 GFLOPS
#
# Scaled weight_decay = 0.0005
# Optimizer groups: 110 .bias, 110 conv.weight, 107 other
# WARNING: --img-size 200 must be multiple of max stride 32, updating to 224
# WARNING: --img-size 200 must be multiple of max stride 32, updating to 224
# train: Scanning '/content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/train/labels.cache' for images and labels... 614 found, 0 missing, 0 empty, 0 corrupted: 100% 614/614 [00:00<?, ?it/s]
# train: Caching images (0.1GB): 100% 614/614 [00:00<00:00, 681.81it/s]
# val: Scanning '/content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/val/labels' for images and labels... 0 found, 154 missing, 0 empty, 0 corrupted: 100% 154/154 [00:00<00:00, 518.74it/s]
# val: WARNING: No labels found in /content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/val/labels.cache. See https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data
# val: New cache created: /content/drive/MyDrive/Projects/Sign Detection/box_detection/post_resized/val/labels.cache
# val: Caching images (0.0GB): 100% 154/154 [00:00<00:00, 660.53it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.78, Best Possible Recall (BPR) = 1.0000
# Image sizes 224 train, 224 test
# Using 4 dataloader workers
# Logging results to runs/train/yolov5s_results2
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       0/99     1.55G   0.09582   0.02169         0    0.1175        18       224: 100% 39/39 [00:08<00:00,  4.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.42it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       1/99     1.97G   0.07906   0.02564         0    0.1047        20       224: 100% 39/39 [00:06<00:00,  6.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.97it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       2/99     1.97G    0.0753   0.02483         0    0.1001        18       224: 100% 39/39 [00:06<00:00,  6.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.14it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       3/99     1.97G   0.07323   0.02547         0   0.09871        17       224: 100% 39/39 [00:06<00:00,  6.33it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.63it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       4/99     1.97G    0.0715   0.02526         0   0.09676        13       224: 100% 39/39 [00:05<00:00,  7.03it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.93it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       5/99     1.97G   0.07048   0.02527         0   0.09575        24       224: 100% 39/39 [00:05<00:00,  7.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.34it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       6/99     1.97G   0.07035   0.02546         0   0.09581        18       224: 100% 39/39 [00:05<00:00,  7.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.36it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       7/99     1.97G   0.06841    0.0263         0    0.0947        21       224: 100% 39/39 [00:05<00:00,  7.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.87it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       8/99     1.97G   0.06697   0.02556         0   0.09253        20       224: 100% 39/39 [00:05<00:00,  7.17it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.60it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       9/99     1.97G   0.06639   0.02657         0   0.09296        18       224: 100% 39/39 [00:05<00:00,  7.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.68it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      10/99     1.97G   0.06305   0.02628         0   0.08933        15       224: 100% 39/39 [00:05<00:00,  7.21it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.51it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      11/99     1.97G   0.06026   0.02655         0   0.08681        21       224: 100% 39/39 [00:05<00:00,  7.15it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.85it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      12/99     1.97G   0.05897   0.02624         0   0.08521        18       224: 100% 39/39 [00:05<00:00,  7.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.06it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      13/99     1.97G   0.05385   0.02644         0   0.08029        14       224: 100% 39/39 [00:05<00:00,  7.51it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.33it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      14/99     1.97G   0.05112   0.02604         0   0.07716        20       224: 100% 39/39 [00:05<00:00,  7.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.21it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      15/99     1.97G   0.04685   0.02521         0   0.07205        19       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.07it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      16/99     1.97G   0.04408   0.02469         0   0.06877        11       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.25it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      17/99     1.97G    0.0419   0.02281         0   0.06471        18       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.99it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      18/99     1.97G   0.03901   0.02132         0   0.06033        16       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.93it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      19/99     1.97G   0.03653   0.01995         0   0.05647        18       224: 100% 39/39 [00:05<00:00,  7.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.12it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      20/99     1.97G   0.03425   0.01957         0   0.05382        20       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.06it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      21/99     1.97G   0.03467   0.01911         0   0.05378        22       224: 100% 39/39 [00:05<00:00,  7.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.14it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      22/99     1.97G    0.0325     0.018         0    0.0505        19       224: 100% 39/39 [00:05<00:00,  7.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.22it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      23/99     1.97G   0.02974   0.01776         0    0.0475        18       224: 100% 39/39 [00:05<00:00,  7.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.04it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      24/99     1.97G    0.0285   0.01653         0   0.04503        19       224: 100% 39/39 [00:05<00:00,  7.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.27it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      25/99     1.97G   0.02722   0.01602         0   0.04323        21       224: 100% 39/39 [00:05<00:00,  7.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.99it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      26/99     1.97G   0.02616   0.01588         0   0.04204        22       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.14it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      27/99     1.97G   0.02423   0.01508         0   0.03931        15       224: 100% 39/39 [00:05<00:00,  7.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.25it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      28/99     1.97G   0.02303   0.01501         0   0.03804        17       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.63it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      29/99     1.97G   0.02226   0.01369         0   0.03595        11       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.54it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      30/99     1.97G   0.02157   0.01363         0   0.03521        13       224: 100% 39/39 [00:05<00:00,  7.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.62it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      31/99     1.97G   0.02139   0.01344         0   0.03483        15       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.22it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      32/99     1.97G   0.01958   0.01283         0   0.03241        14       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.66it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      33/99     1.97G   0.01965   0.01338         0   0.03303        19       224: 100% 39/39 [00:05<00:00,  7.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.61it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      34/99     1.97G   0.01854   0.01233         0   0.03086        22       224: 100% 39/39 [00:05<00:00,  7.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.85it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      35/99     1.97G   0.01901   0.01186         0   0.03088        16       224: 100% 39/39 [00:05<00:00,  7.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.68it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      36/99     1.97G   0.01783   0.01174         0   0.02958        17       224: 100% 39/39 [00:05<00:00,  7.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.85it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      37/99     1.97G   0.01791   0.01171         0   0.02962        19       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.83it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      38/99     1.97G   0.01695   0.01178         0   0.02874        20       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.94it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      39/99     1.97G   0.01759   0.01107         0   0.02866        19       224: 100% 39/39 [00:05<00:00,  7.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.79it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      40/99     1.97G   0.01678   0.01078         0   0.02756        18       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.70it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      41/99     1.97G   0.01564    0.0108         0   0.02643        18       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.85it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      42/99     1.97G   0.01566   0.01025         0    0.0259        17       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.00it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      43/99     1.97G    0.0151   0.01011         0   0.02522        17       224: 100% 39/39 [00:05<00:00,  7.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.89it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      44/99     1.97G   0.01541  0.009872         0   0.02528        16       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.92it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      45/99     1.97G   0.01421  0.009891         0    0.0241        15       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.98it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      46/99     1.97G   0.01467  0.009789         0   0.02446        16       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.87it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      47/99     1.97G   0.01414  0.009961         0    0.0241        18       224: 100% 39/39 [00:05<00:00,  7.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.06it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      48/99     1.97G   0.01446   0.00943         0   0.02389        12       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.49it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      49/99     1.97G   0.01416  0.009597         0   0.02375        18       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.03it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      50/99     1.97G   0.01348   0.00901         0   0.02249        16       224: 100% 39/39 [00:05<00:00,  7.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.05it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      51/99     1.97G   0.01369  0.009286         0   0.02297        19       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.08it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      52/99     1.97G   0.01298  0.008845         0   0.02182        18       224: 100% 39/39 [00:05<00:00,  7.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.89it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      53/99     1.97G   0.01319  0.009092         0   0.02229        20       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.98it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      54/99     1.97G   0.01246  0.008692         0   0.02115        15       224: 100% 39/39 [00:05<00:00,  7.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.05it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      55/99     1.97G   0.01256  0.008828         0   0.02139        15       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.00it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      56/99     1.97G   0.01204  0.008272         0   0.02031        19       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.03it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      57/99     1.97G   0.01227  0.008668         0   0.02094        17       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.97it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      58/99     1.97G   0.01193  0.008576         0    0.0205        24       224: 100% 39/39 [00:05<00:00,  7.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.84it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      59/99     1.97G   0.01112  0.008133         0   0.01925        19       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.07it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      60/99     1.97G    0.0117  0.008577         0   0.02028        20       224: 100% 39/39 [00:05<00:00,  7.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.02it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      61/99     1.97G   0.01172  0.008451         0   0.02017        15       224: 100% 39/39 [00:05<00:00,  7.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.91it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      62/99     1.97G   0.01078  0.008139         0   0.01892        18       224: 100% 39/39 [00:05<00:00,  7.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.85it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      63/99     1.97G   0.01152  0.007984         0   0.01951        20       224: 100% 39/39 [00:05<00:00,  7.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.98it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      64/99     1.97G   0.01054  0.007973         0   0.01851        20       224: 100% 39/39 [00:05<00:00,  7.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.09it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      65/99     1.97G   0.01035  0.008042         0   0.01839        18       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.78it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      66/99     1.97G  0.009922  0.007855         0   0.01778        22       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.04it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      67/99     1.97G   0.01015  0.007543         0   0.01769        16       224: 100% 39/39 [00:05<00:00,  7.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.39it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      68/99     1.97G   0.01032  0.007651         0   0.01797        19       224: 100% 39/39 [00:05<00:00,  7.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.57it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      69/99     1.97G   0.01002  0.007236         0   0.01726        16       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.00it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      70/99     1.97G  0.009312  0.007298         0   0.01661        17       224: 100% 39/39 [00:05<00:00,  7.44it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.82it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      71/99     1.97G  0.009775  0.007257         0   0.01703        18       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.99it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      72/99     1.97G  0.009445  0.007247         0   0.01669        18       224: 100% 39/39 [00:05<00:00,  7.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.02it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      73/99     1.97G  0.009105  0.007105         0   0.01621        15       224: 100% 39/39 [00:05<00:00,  7.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.96it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      74/99     1.97G   0.00878  0.007048         0   0.01583        18       224: 100% 39/39 [00:05<00:00,  6.98it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.00it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      75/99     1.97G  0.008625  0.006976         0    0.0156        17       224: 100% 39/39 [00:05<00:00,  7.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.03it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      76/99     1.97G  0.008382  0.007101         0   0.01548        22       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.06it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      77/99     1.97G  0.008714  0.006593         0   0.01531        16       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.98it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      78/99     1.97G  0.008518  0.006961         0   0.01548        17       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.10it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      79/99     1.97G  0.008421  0.006899         0   0.01532        20       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.96it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      80/99     1.97G  0.008439  0.006683         0   0.01512        19       224: 100% 39/39 [00:05<00:00,  7.51it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.03it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      81/99     1.97G  0.008167  0.006678         0   0.01485        20       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.05it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      82/99     1.97G  0.007933  0.006733         0   0.01467        17       224: 100% 39/39 [00:05<00:00,  7.51it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.82it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      83/99     1.97G  0.007967   0.00648         0   0.01445        22       224: 100% 39/39 [00:05<00:00,  7.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.86it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      84/99     1.97G  0.008003  0.006433         0   0.01444        22       224: 100% 39/39 [00:05<00:00,  7.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.86it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      85/99     1.97G  0.007559   0.00663         0   0.01419        21       224: 100% 39/39 [00:05<00:00,  7.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.41it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      86/99     1.97G  0.007801  0.006488         0   0.01429        19       224: 100% 39/39 [00:05<00:00,  7.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.94it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      87/99     1.97G  0.007808  0.006602         0   0.01441        20       224: 100% 39/39 [00:05<00:00,  7.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.94it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      88/99     1.97G  0.007354  0.006143         0    0.0135        20       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.83it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      89/99     1.97G  0.007337  0.006362         0    0.0137        17       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.01it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      90/99     1.97G  0.007261  0.006056         0   0.01332        21       224: 100% 39/39 [00:05<00:00,  7.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.06it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      91/99     1.97G  0.007267  0.006524         0   0.01379        15       224: 100% 39/39 [00:05<00:00,  7.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.94it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      92/99     1.97G  0.007244  0.006505         0   0.01375        21       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.10it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      93/99     1.97G  0.007324  0.006173         0    0.0135        21       224: 100% 39/39 [00:05<00:00,  7.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.99it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      94/99     1.97G  0.006882  0.006224         0   0.01311        20       224: 100% 39/39 [00:05<00:00,  7.47it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.09it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      95/99     1.97G  0.006993   0.00597         0   0.01296        18       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.99it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      96/99     1.97G  0.007222  0.006399         0   0.01362        21       224: 100% 39/39 [00:05<00:00,  7.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.98it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      97/99     1.97G  0.007045  0.006044         0   0.01309        23       224: 100% 39/39 [00:05<00:00,  7.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  9.86it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      98/99     1.97G  0.006696  0.006003         0    0.0127        17       224: 100% 39/39 [00:05<00:00,  7.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00, 10.08it/s]
#                  all         154           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      99/99     1.97G  0.006627  0.005899         0   0.01253        15       224: 100% 39/39 [00:05<00:00,  7.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.22it/s]
#                  all         154           0           0           0           0           0
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# Optimizer stripped from runs/train/yolov5s_results2/weights/last.pt, 93.7MB
# Optimizer stripped from runs/train/yolov5s_results2/weights/best.pt, 93.7MB
# 100 epochs completed in 0.247 hours.
#
# CPU times: user 9.48 s, sys: 1.59 s, total: 11.1 s
# Wall time: 15min 9s

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 496), started 0:15:57 ago. (Use '!kill 496' to kill it.)

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/runs/train/yolov5s_results2/results.png', width=1000)  # view results.png

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/runs/train/yolov5s_results2/test_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights

# %% [markdown]
# ### DETECTOR

# %% [markdown]
# detect.py 꼭 바꿔주기
# save_path 잘 지정하기

# %%
# ### yolov5 detected object cropper
# ### set result location
# ### rename the file

# import argparse
# import os
# import time
# from pathlib import Path
# import numpy as np
# import random

# import cv2
# import torch
# import torch.backends.cudnn as cudnn
# from numpy import random

# from models.experimental import attempt_load
# from utils.datasets import LoadStreams, LoadImages
# from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
#     scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
# from utils.plots import plot_one_box
# from utils.torch_utils import select_device, load_classifier, time_synchronized


# def detect(save_img=False):
#     source, weights, view_img, save_txt, imgsz = opt.source, opt.weights, opt.view_img, opt.save_txt, opt.img_size
#     webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(
#         ('rtsp://', 'rtmp://', 'http://'))

#     # Directories
#     save_dir = Path(increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok))  # increment run
#     (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir

#     # Initialize
#     set_logging()
#     device = select_device(opt.device)
#     half = device.type != 'cpu'  # half precision only supported on CUDA

#     # Load model
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#     stride = int(model.stride.max())  # model stride
#     imgsz = check_img_size(imgsz, s=stride)  # check img_size
#     if half:
#         model.half()  # to FP16

#     # Second-stage classifier
#     classify = False
#     if classify:
#         modelc = load_classifier(name='resnet101', n=2)  # initialize
#         modelc.load_state_dict(torch.load('weights/resnet101.pt', map_location=device)['model']).to(device).eval()

#     # Set Dataloader
#     vid_path, vid_writer = None, None
#     if webcam:
#         view_img = check_imshow()
#         cudnn.benchmark = True  # set True to speed up constant image size inference
#         dataset = LoadStreams(source, img_size=imgsz, stride=stride)
#     else:
#         save_img = True
#         dataset = LoadImages(source, img_size=imgsz, stride=stride)

#     # Get names and colors
#     names = model.module.names if hasattr(model, 'module') else model.names
#     colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]

#     # Run inference
#     if device.type != 'cpu':
#         model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))  # run once
#     t0 = time.time()
#     for path, img, im0s, vid_cap in dataset:
#         img = torch.from_numpy(img).to(device)
#         img = img.half() if half else img.float()  # uint8 to fp16/32
#         img /= 255.0  # 0 - 255 to 0.0 - 1.0
#         if img.ndimension() == 3:
#             img = img.unsqueeze(0)

#         # Inference
#         t1 = time_synchronized()
#         pred = model(img, augment=opt.augment)[0]

#         # Apply NMS
#         pred = non_max_suppression(pred, opt.conf_thres, opt.iou_thres, classes=opt.classes, agnostic=opt.agnostic_nms)
#         t2 = time_synchronized()

#         # Apply Classifier
#         if classify:
#             pred = apply_classifier(pred, modelc, img, im0s)

#         # Process detections
#         for i, det in enumerate(pred):  # detections per image
#             if webcam:  # batch_size >= 1
#                 p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
#             else:
#                 p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)

#             p = Path(p)  # to Path
#             save_path = str(save_dir / p.name)  # img.jpg
#             txt_path = str(save_dir / 'labels' / p.stem) + ('' if dataset.mode == 'image' else f'_{frame}')  # img.txt
#             s += '%gx%g ' % img.shape[2:]  # print string
#             gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
#             if len(det):
#                 # Rescale boxes from img_size to im0 size
#                 det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

#                 # Print results
#                 for c in det[:, -1].unique():
#                     n = (det[:, -1] == c).sum()  # detections per class
#                     s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

#                 # Write results
#                  # Write results
#                 for *xyxy, conf, cls in det:
#                     if save_txt:  # Write to file
#                         xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
#                         with open(txt_path + '.txt', 'a') as f:
#                             f.write(('%g ' * 5 + '\n') % (cls, *xywh))  # label format
                    
#                     if save_img or view_img:  # Add bbox to image
#                         label = '%s %.2f' % (names[int(cls)], conf)
#                         plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=3)
                    
#                     save_obj = True
#                     if save_obj:
#                         for k in range(len(det)):
#                             x,y,w,h=int(xyxy[0]), int(xyxy[1]), int(xyxy[2] - xyxy[0]), int(xyxy[3] - xyxy[1])                   
#                             img_ = im0.astype(np.uint8)
#                             crop_img=img_[y:y+ h, x:x + w]                          
                                
#                             #!!rescale image !!!

#                             random_num = random.randint(1,100)
#                             filename=p.name
#                             # print(filename)
#                             filepath='/content/post_resized/test/results/'
#                             print(filepath+'{}_'.format(random_num)+filename)
#                             cv2.imwrite(filepath+'{}_'.format(random_num)+filename, crop_img) 
                            
#                         else:
#                             print("There is no detected object")
#                             continue

#             # Print time (inference + NMS)
#             print(f'{s}Done. ({t2 - t1:.3f}s)')

#             # Stream results
#             if view_img:
#                 cv2.imshow(str(p), im0)
#                 cv2.waitKey(1)  # 1 millisecond

#             # Save results (image with detections)
#             if save_img:
#                 if dataset.mode == 'image':
#                     cv2.imwrite(save_path, im0)
#                 else:  # 'video'
#                     if vid_path != save_path:  # new video
#                         vid_path = save_path
#                         if isinstance(vid_writer, cv2.VideoWriter):
#                             vid_writer.release()  # release previous video writer

#                         fourcc = 'mp4v'  # output video codec
#                         fps = vid_cap.get(cv2.CAP_PROP_FPS)
#                         w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#                         h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#                         vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*fourcc), fps, (w, h))
#                     vid_writer.write(im0)

#     if save_txt or save_img:
#         s = f"\n{len(list(save_dir.glob('labels/*.txt')))} labels saved to {save_dir / 'labels'}" if save_txt else ''
#         print(f"Results saved to {save_dir}{s}")

#     print(f'Done. ({time.time() - t0:.3f}s)')


# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--weights', nargs='+', type=str, default='yolov5s.pt', help='model.pt path(s)')
#     parser.add_argument('--source', type=str, default='data/images', help='source')  # file/folder, 0 for webcam
#     parser.add_argument('--img-size', type=int, default=640, help='inference size (pixels)')
#     parser.add_argument('--conf-thres', type=float, default=0.25, help='object confidence threshold')
#     parser.add_argument('--iou-thres', type=float, default=0.45, help='IOU threshold for NMS')
#     parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
#     parser.add_argument('--view-img', action='store_true', help='display results')
#     parser.add_argument('--save-txt', action='store_true', help='save results to *.txt')
#     parser.add_argument('--save-conf', action='store_true', help='save confidences in --save-txt labels')
#     parser.add_argument('--classes', nargs='+', type=int, help='filter by class: --class 0, or --class 0 2 3')
#     parser.add_argument('--agnostic-nms', action='store_true', help='class-agnostic NMS')
#     parser.add_argument('--augment', action='store_true', help='augmented inference')
#     parser.add_argument('--update', action='store_true', help='update all models')
#     parser.add_argument('--project', default='runs/detect', help='save results to project/name')
#     parser.add_argument('--name', default='exp', help='save results to project/name')
#     parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
#     opt = parser.parse_args()
#     print(opt)
#     check_requirements(exclude=('pycocotools', 'thop'))

#     with torch.no_grad():
#         if opt.update:  # update all models (to fix SourceChangeWarning)
#             for opt.weights in ['yolov5s.pt', 'yolov5m.pt', 'yolov5l.pt', 'yolov5x.pt']:
#                 detect()
#                 strip_optimizer(opt.weights)
#         else:
#             detect()

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5
# !python box_detect.py --weights runs/train/yolov5s_results2/weights/best.pt --img 1000 --conf 0.9 --source ../post_resized/test/images
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/6_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/6_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/18_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/86_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/20_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/67_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/7_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/26_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/68_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/4_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/67_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/13_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/82_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/86_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/34_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/98_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/30_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/57_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/42_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/30_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/26_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/97_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/84_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/21_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/21_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/77_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/52_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/34_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/47_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/13_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/78_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/68_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/50_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/86_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/84_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/13_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/76_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/20_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/53_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/32_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/21_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/92_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/48_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/2_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/68_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/7_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/53_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/7_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/36_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/20_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/12_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/30_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/76_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/36_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/67_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/20_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/53_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/32_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/82_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/30_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/6_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/50_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/47_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/97_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/98_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/53_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/72_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/26_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/32_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/36_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/62_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/6_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/6_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/39_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/52_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/26_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/76_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/51_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/78_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/34_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/34_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/82_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/57_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/48_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/92_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/77_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/18_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/5_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/4_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/28_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/13_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/77_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/84_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/10_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/36_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/26_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/41_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/77_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/52_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/76_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/86_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_153341.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/39_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/36_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/24_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/53_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/57_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/65_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/52_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/93_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/88_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_153341.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_153341.jpg
# ...
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/21_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/97_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_172825.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/98_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/77_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/90_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/97_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/42_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/68_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/57_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/54_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/7_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/42_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/46_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/40_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/15_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/86_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/38_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_172825.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/3_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/72_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/7_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/56_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/94_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/92_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/50_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/47_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/59_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/99_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/69_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/98_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/20_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/50_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/47_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/2_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_172825.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/62_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/49_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/17_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/43_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/62_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/73_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/81_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/60_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/84_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/8_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/55_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/37_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/87_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/45_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/1_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/42_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/63_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/80_20220126_172825.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/42_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/71_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/83_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/95_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/23_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/85_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/89_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/97_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/22_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/9_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/44_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/25_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/79_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/14_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/52_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/91_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/68_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/96_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/66_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/50_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/64_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/4_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/74_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/58_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/29_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/35_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/70_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/16_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/61_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/11_20220126_172825.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/33_20220126_172825.jpg
# There is no detected object
# 1024x832 35 boxs, Done. (0.047s)
# image 5/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/6.jpg: 1024x832 Done. (0.046s)
# image 6/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/A-LOADED-CONTAINER.jpg: /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/19_A-LOADED-CONTAINER.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/31_A-LOADED-CONTAINER.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/27_A-LOADED-CONTAINER.jpg
# /content/drive/MyDrive/Projects/Sign Detection/box_detection/test/result/75_A-LOADED-CONTAINER.jpg
# There is no detected object
# 1024x832 2 boxs, Done. (0.047s)
# image 7/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/Floor-Loaded-vs-Palletized-Blog-Picture.jpg: 1024x832 Done. (0.046s)
# image 8/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/bc754145-66cc-4b91-8b51-6982883bbffc.jpg: 1024x832 Done. (0.046s)
# image 9/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/dwyhr (1).jpg: 1024x832 Done. (0.047s)
# image 10/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/dwyhr (11).jpg: 1024x832 Done. (0.046s)
# image 11/11 /content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/../post_resized/test/images/dwyhr (9).jpg: 1024x832 Done. (0.046s)
# Results saved to runs/detect/exp4
# Done. (61.601s)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/drive/MyDrive/Projects/Sign Detection/box_detection/yolov5/runs/detect/exp4/20220126_172825.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# ### EXPORT

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/MyDrive

# %%
torch.save
